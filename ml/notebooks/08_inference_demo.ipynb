# %% [markdown]
# # 08 - Inference Demo
#
# Stable interface consumed by the backend (Phase 4):

# %%
from data_pipeline.src.schemas.network_state import NetworkStateSequence
from ml.src.inference.predictor import WorldModelPredictor

predictor = WorldModelPredictor.load('ml/artifacts', device='cpu')
# seq = NetworkStateSequence.model_validate_json(open('sequences.jsonl').readline())
# result = predictor.predict(seq, explain=True)
# result.risk_score, result.malicious_probability, result.confidence

# %%
# K-step forward simulation
# entries = predictor.rollout(seq, horizon=3)
# [(e.step, e.timestamp, e.features['port_scan_score'], e.confidence) for e in entries]

# %%
# Explainability hooks (Phase 5 consumes these)
# attn = predictor.get_attentions(seq)        # per-layer [L, L]
# contribs = predictor.attribute_features(seq) # gradient saliency
