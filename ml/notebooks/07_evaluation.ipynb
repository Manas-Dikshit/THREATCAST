# %% [markdown]
# # 07 - Evaluation
#
# Compares the world model against the Logistic Regression baseline on the
# chronological test tail. CLI: `python -m ml.src.evaluation.evaluate`

# %%
python -m ml.src.evaluation.evaluate --dataset-dir ml/artifacts --artifacts-dir ml/artifacts

# %%
import json
report = json.load(open('ml/artifacts/evaluation_report.json'))
report

# %% [markdown]
# Interpretation rules: never claim superiority without both classes present;
# temporal quality is judged by next-state MSE/MAE/R2, classification by F1/FPR.
