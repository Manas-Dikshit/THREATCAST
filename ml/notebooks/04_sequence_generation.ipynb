# %% [markdown]
# # 04 - Sequence Generation
#
# Sequences come from `data_pipeline/src/windows/sequences.py`: sliding L=5
# windows over contiguous 10 s states, no gap spanning, target S(t+K) inside run.

# %%
from data_pipeline.src.windows.sequences import build_sequences, contiguous_runs
print(build_sequences.__doc__)
print(contiguous_runs.__doc__)

# %%
from pathlib import Pathimport jsonp = Path('ml/artifacts/sequences.jsonl')seqs = [json.loads(l) for l in p.open()] if p.exists() else []len(seqs)
